# %% [markdown]
# # Notebook content
#
# 1. Import Necessary Libraries
# 2. Webscraping
# 3. Scraping with Selenium

# %% [markdown]
# ### 1. Imports

# %%
import requests
import time
import pandas as pd
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 2. Webscraping
#
# ### 2.1 Download HTML files

# %%
#Create a list of years we want to analyze
years = list(range(1980,2025))

#Base url to website
url_start = 'https://www.basketball-reference.com/leagues/NBA_{}.html'

#Download each page for each year from website
for year in years:
    url = url_start.format(year) # Replace placeholder in url_start with year
    data = requests.get(url)
    
    #Save HTML to a file
    with open('stats/{}.html'.format(year), 'w+', encoding='utf-8') as f:
        f.write(data.text)
    
    #Pause in between requests to avoid overwhelming the server
    time.sleep(15)

# %% [markdown]
# ### 2.2  Extracting tables from Downloaded HTML Files

# %%
#Testing for one page first
with open('stats/1980.html', encoding='utf-8') as f:
    page = f.read()

# %%
#Parse the HTML content of a web page
soup = BeautifulSoup(page,'html.parser')

# %%
#Extract desired table using their id
team_stats_per_game = soup.find(id='div_per_game-team')

# %%
per_game_1980 = pd.read_html(str(team_stats_per_game))[0]
# Out:
# C:\Users\Michael 2023\AppData\Local\Temp\ipykernel_14060\3715190264.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   per_game_1980 = pd.read_html(str(team_stats_per_game))[0]

# %%
per_game_1980
# Out:
#       Rk                     Team   G     MP    FG   FGA    FG%   3P  3PA  \
# 0    1.0       San Antonio Spurs*  82  240.9  47.0  94.4  0.498  0.6  2.5
# 1    2.0      Los Angeles Lakers*  82  242.4  47.5  89.9  0.529  0.2  1.2
# 2    3.0      Cleveland Cavaliers  82  243.0  46.5  98.1  0.474  0.4  2.3
# 3    4.0          New York Knicks  82  241.2  46.4  93.6  0.496  0.5  2.3
# 4    5.0          Boston Celtics*  82  242.4  44.1  90.1  0.490  2.0  5.1
# 5    6.0           Indiana Pacers  82  242.1  44.4  93.8  0.473  1.1  3.8
# 6    7.0            Phoenix Suns*  82  240.9  43.5  88.2  0.493  0.8  3.4
# 7    8.0         Houston Rockets*  82  243.0  43.9  91.4  0.480  1.3  4.6
# 8    9.0         Milwaukee Bucks*  82  241.5  44.9  92.1  0.488  0.6  1.9
# 9   10.0      Philadelphia 76ers*  82  242.1  43.0  87.3  0.492  0.3  1.5
# 10  11.0          Detroit Pistons  82  241.2  44.4  92.6  0.480  0.7  2.7
# 11  12.0     Seattle SuperSonics*  82  241.8  43.3  92.3  0.470  0.7  2.3
# 12  13.0          New Jersey Nets  82  241.5  42.1  91.5  0.461  1.0  3.6
# 13  14.0           Denver Nuggets  82  241.8  42.2  91.1  0.463  1.0  3.1
# 14  15.0       Kansas City Kings*  82  241.5  43.7  91.3  0.478  0.3  1.4
# 15  16.0       San Diego Clippers  82  240.9  43.0  91.4  0.470  2.2  6.6
# 16  17.0            Chicago Bulls  82  242.7  41.0  84.7  0.484  0.9  3.4
# 17  18.0      Washington Bullets*  82  242.4  43.6  95.1  0.458  0.9  2.9
# 18  19.0           Atlanta Hawks*  82  241.2  39.8  85.7  0.464  0.2  0.9
# 19  20.0    Golden State Warriors  82  242.4  43.0  89.2  0.482  0.3  1.5
# 20  21.0  Portland Trail Blazers*  82  241.2  41.6  87.4  0.476  0.3  1.6
# 21  22.0                Utah Jazz  82  241.5  41.2  83.1  0.496  0.7  2.3
# 22   NaN           League Average  82  241.8  43.6  90.6  0.481  0.8  2.8
#
#       3P%  ...    FT%   ORB   DRB   TRB   AST   STL  BLK   TOV    PF    PTS
# 0   0.252  ...  0.801  14.1  30.7  44.7  28.4   9.4  4.1  19.4  25.6  119.4
# 1   0.200  ...  0.775  13.2  32.4  45.6  29.4   9.4  6.7  20.0  21.8  115.1
# 2   0.193  ...  0.772  15.9  29.0  45.0  25.7   9.3  4.2  16.7  23.6  114.1
# 3   0.220  ...  0.747  15.1  28.1  43.2  27.6  10.7  5.6  19.7  26.4  114.0
# 4   0.384  ...  0.779  15.0  30.0  44.9  26.8   9.9  3.8  18.8  24.1  113.5
# 5   0.280  ...  0.751  17.0  28.4  45.4  26.2  11.0  6.5  18.5  24.1  111.2
# 6   0.243  ...  0.773  13.1  30.0  43.0  27.8  11.1  4.2  19.9  22.6  111.1
# 7   0.274  ...  0.766  17.0  27.0  44.0  26.2   9.5  4.5  19.1  23.5  110.8
# 8   0.323  ...  0.764  15.2  29.2  44.4  27.8   9.5  6.2  18.2  23.6  110.1
# 9   0.216  ...  0.772  14.5  32.1  46.6  27.1   9.7  8.0  20.8  22.7  109.1
# 10  0.260  ...  0.740  15.0  29.5  44.4  23.8   9.5  6.9  21.2  25.2  108.9
# 11  0.312  ...  0.768  16.8  31.1  47.9  24.9   9.1  5.2  18.2  22.7  108.5
# 12  0.285  ...  0.782  15.0  30.9  45.9  25.5  10.6  7.1  20.8  26.6  108.3
# 13  0.325  ...  0.737  16.0  30.8  46.8  25.4   9.1  4.9  18.7  23.4  108.3
# 14  0.219  ...  0.743  14.5  29.6  44.1  25.9  10.5  4.3  17.5  26.0  108.0
# 15  0.326  ...  0.736  15.8  28.1  43.9  20.6   8.1  3.5  17.6  23.1  107.6
# 16  0.255  ...  0.779  13.6  30.1  43.7  26.2   8.6  4.8  20.5  26.2  107.5
# 17  0.307  ...  0.758  16.3  33.2  49.5  26.8   6.5  5.4  16.8  23.1  107.0
# 18  0.173  ...  0.771  16.7  29.3  46.0  23.3   9.5  6.6  18.2  28.0  104.5
# 19  0.223  ...  0.738  14.1  29.7  43.8  24.7   9.5  4.1  18.2  25.4  103.6
# 20  0.197  ...  0.743  15.8  29.4  45.2  23.1   8.6  5.8  18.9  23.9  102.5
# 21  0.319  ...  0.809  11.8  28.8  40.6  24.5   8.0  4.4  18.8  24.5  102.4
# 22  0.280  ...  0.764  15.1  29.9  44.9  25.8   9.4  5.3  18.9  24.4  109.3
#
# [23 rows x 25 columns]

# %% [markdown]
# ### 2.3 Stats Per Game Table

# %%
#Lets extract team stats table for every year
#Placeholder for stats tables
df = []

for year in years:
    with open('stats/{}.html'.format(year), encoding='utf-8') as f:
        page = f.read()
    
    soup = BeautifulSoup(page, 'html.parser')
    team_stats_per_game = soup.find(id='div_per_game-team')
    per_game = pd.read_html(str(team_stats_per_game))[0]
    per_game['Year'] = year
    
    df.append(per_game)

# %%
#Convert df into pandas dataframe
team_stats = pd.concat(df)

# %%
#Explore team_stats
team_stats.head()
# Out:
#     Rk                 Team   G     MP    FG   FGA    FG%   3P  3PA    3P%  \
# 0  1.0   San Antonio Spurs*  82  240.9  47.0  94.4  0.498  0.6  2.5  0.252
# 1  2.0  Los Angeles Lakers*  82  242.4  47.5  89.9  0.529  0.2  1.2  0.200
# 2  3.0  Cleveland Cavaliers  82  243.0  46.5  98.1  0.474  0.4  2.3  0.193
# 3  4.0      New York Knicks  82  241.2  46.4  93.6  0.496  0.5  2.3  0.220
# 4  5.0      Boston Celtics*  82  242.4  44.1  90.1  0.490  2.0  5.1  0.384
#
#    ...   ORB   DRB   TRB   AST   STL  BLK   TOV    PF    PTS  Year
# 0  ...  14.1  30.7  44.7  28.4   9.4  4.1  19.4  25.6  119.4  1980
# 1  ...  13.2  32.4  45.6  29.4   9.4  6.7  20.0  21.8  115.1  1980
# 2  ...  15.9  29.0  45.0  25.7   9.3  4.2  16.7  23.6  114.1  1980
# 3  ...  15.1  28.1  43.2  27.6  10.7  5.6  19.7  26.4  114.0  1980
# 4  ...  15.0  30.0  44.9  26.8   9.9  3.8  18.8  24.1  113.5  1980
#
# [5 rows x 26 columns]

# %%
#Some missing values in RK 
team_stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1299 entries, 0 to 30
# Data columns (total 26 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rk      1254 non-null   float64
#  1   Team    1299 non-null   object
#  2   G       1299 non-null   int64
#  3   MP      1299 non-null   float64
#  4   FG      1299 non-null   float64
#  5   FGA     1299 non-null   float64
#  6   FG%     1299 non-null   float64
#  7   3P      1299 non-null   float64
#  8   3PA     1299 non-null   float64
#  9   3P%     1299 non-null   float64
#  10  2P      1299 non-null   float64
#  11  2PA     1299 non-null   float64
#  12  2P%     1299 non-null   float64
#  13  FT      1299 non-null   float64
#  14  FTA     1299 non-null   float64
#  15  FT%     1299 non-null   float64
#  16  ORB     1299 non-null   float64
#  17  DRB     1299 non-null   float64
#  18  TRB     1299 non-null   float64
#  19  AST     1299 non-null   float64
#  20  STL     1299 non-null   float64
#  21  BLK     1299 non-null   float64
#  22  TOV     1299 non-null   float64
#  23  PF      1299 non-null   float64
#  24  PTS     1299 non-null   float64
#  25  Year    1299 non-null   int64
# dtypes: float64(23), int64(2), object(1)
# memory usage: 274.0+ KB

# %%
#Store dataframe into a csv file
team_stats.to_csv('team_stats.csv')

# %% [markdown]
# ### 2.4 Total Stats Table

# %%
#Lets extract total stats table for every year
df2 = []

for year in years:
    with open('stats/{}.html'.format(year), encoding='utf-8') as f:
        page = f.read()
    
    soup = BeautifulSoup(page, 'html.parser')
    team_stats_total = soup.find(id='all_totals_team-opponent')
    stats_total = pd.read_html(str(team_stats_total))[0]
    stats_total['Year'] = year
    
    df2.append(stats_total)

# %%
#Convert df into pandas dataframe
total_stats = pd.concat(df2)

# %%
total_stats.tail()
# Out:
#       Rk                    Team   G     MP    FG   FGA    FG%    3P   3PA  \
# 26  27.0         Detroit Pistons  82  19755  3353  7236  0.463   906  2602
# 27  28.0       Charlotte Hornets  82  19730  3281  7133  0.460   989  2788
# 28  29.0  Portland Trail Blazers  82  19880  3227  7356  0.439   939  2723
# 29  30.0       Memphis Grizzlies  82  19780  3145  7230  0.435  1071  3097
# 30   NaN          League Average  82  19792  3458  7290  0.474  1053  2879
#
#       3P%  ...   ORB   DRB   TRB   AST  STL  BLK   TOV    PF   PTS  Year
# 26  0.348  ...   861  2692  3553  2088  531  384  1248  1688  9010  2024
# 27  0.355  ...   765  2538  3303  2033  562  371  1129  1472  8740  2024
# 28  0.345  ...  1036  2469  3505  1894  627  354  1249  1654  8722  2024
# 29  0.346  ...   896  2598  3494  2025  673  501  1236  1563  8677  2024
# 30  0.366  ...   865  2705  3570  2187  613  422  1116  1536  9365  2024
#
# [5 rows x 26 columns]

# %%
#Some missing values in RK (once again, no rank for league avg)
total_stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1299 entries, 0 to 30
# Data columns (total 26 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rk      1254 non-null   float64
#  1   Team    1299 non-null   object
#  2   G       1299 non-null   int64
#  3   MP      1299 non-null   int64
#  4   FG      1299 non-null   int64
#  5   FGA     1299 non-null   int64
#  6   FG%     1299 non-null   float64
#  7   3P      1299 non-null   int64
#  8   3PA     1299 non-null   int64
#  9   3P%     1299 non-null   float64
#  10  2P      1299 non-null   int64
#  11  2PA     1299 non-null   int64
#  12  2P%     1299 non-null   float64
#  13  FT      1299 non-null   int64
#  14  FTA     1299 non-null   int64
#  15  FT%     1299 non-null   float64
#  16  ORB     1299 non-null   int64
#  17  DRB     1299 non-null   int64
#  18  TRB     1299 non-null   int64
#  19  AST     1299 non-null   int64
#  20  STL     1299 non-null   int64
#  21  BLK     1299 non-null   int64
#  22  TOV     1299 non-null   int64
#  23  PF      1299 non-null   int64
#  24  PTS     1299 non-null   int64
#  25  Year    1299 non-null   int64
# dtypes: float64(5), int64(20), object(1)
# memory usage: 274.0+ KB

# %%
#Store dataframe into a csv file
total_stats.to_csv('total_stats.csv')

# %% [markdown]
# ### 2.5 Champions

# %%
#Extracting Champions of 1980 (test)
champion = None
with open('rank/1980_standing.html', encoding='utf-8') as f:
        page = f.read()
        soup = BeautifulSoup(page, 'html.parser')
        
for p in soup.find_all('p'):
    if p.find('strong') and 'League Champion' in p.find('strong').text:
        # Extract the text within the <a> tag
        champion = p.find('a').text.strip()
        break

# %%
#Champions of 1980
champion
# Out:
# 'Los Angeles Lakers'

# %%
#Let's extract champions for every year

#Initialize an empty list to store the results
champion_data = []

#Loop through each year
for year in years:
    with open('rank/{}_standing.html'.format(year), encoding='utf-8') as f:
        page = f.read()
        
    soup = BeautifulSoup(page, 'html.parser')
    
    # Find the <p> tag that contains the League Champion information
    champion = None
    for p in soup.find_all('p'):
        if p.find('strong') and 'League Champion' in p.find('strong').text:
            # Extract the text within the <a> tag
            champion = p.find('a').text.strip()
            break
    
    # Append the result to the list
    if champion:
        champion_data.append({'Year': year, 'Champion': champion})

# Convert the list to a DataFrame
Champs = pd.DataFrame(champion_data)

Champs
# Out:
#     Year               Champion
# 0   1980     Los Angeles Lakers
# 1   1981         Boston Celtics
# 2   1982     Los Angeles Lakers
# 3   1983     Philadelphia 76ers
# 4   1984         Boston Celtics
# 5   1985     Los Angeles Lakers
# 6   1986         Boston Celtics
# 7   1987     Los Angeles Lakers
# 8   1988     Los Angeles Lakers
# 9   1989        Detroit Pistons
# 10  1990        Detroit Pistons
# 11  1991          Chicago Bulls
# 12  1992          Chicago Bulls
# 13  1993          Chicago Bulls
# 14  1994        Houston Rockets
# 15  1995        Houston Rockets
# 16  1996          Chicago Bulls
# 17  1997          Chicago Bulls
# 18  1998          Chicago Bulls
# 19  1999      San Antonio Spurs
# 20  2000     Los Angeles Lakers
# 21  2001     Los Angeles Lakers
# 22  2002     Los Angeles Lakers
# 23  2003      San Antonio Spurs
# 24  2004        Detroit Pistons
# 25  2005      San Antonio Spurs
# 26  2006             Miami Heat
# 27  2007      San Antonio Spurs
# 28  2008         Boston Celtics
# 29  2009     Los Angeles Lakers
# 30  2010     Los Angeles Lakers
# 31  2011       Dallas Mavericks
# 32  2012             Miami Heat
# 33  2013             Miami Heat
# 34  2014      San Antonio Spurs
# 35  2015  Golden State Warriors
# 36  2016    Cleveland Cavaliers
# 37  2017  Golden State Warriors
# 38  2018  Golden State Warriors
# 39  2019        Toronto Raptors
# 40  2020     Los Angeles Lakers
# 41  2021        Milwaukee Bucks
# 42  2022  Golden State Warriors
# 43  2023         Denver Nuggets
# 44  2024         Boston Celtics

# %%
#Store dataframe into a csv file
Champs.to_csv('champions.csv')

# %% [markdown]
# ### 3. Scraping with Selenium
# - The goal is extract the team standings for each year
# - Use selenium to help scrape dynamic tables containing this information

# %%
# !pip install selenium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting selenium
#   Downloading selenium-4.23.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\programdata\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (2.0.7)
# Collecting trio~=0.17 (from selenium)
#   Downloading trio-0.26.2-py3-none-any.whl.metadata (8.6 kB)
# Collecting trio-websocket~=0.9 (from selenium)
#   Downloading trio_websocket-0.11.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: certifi>=2021.10.8 in c:\programdata\anaconda3\lib\site-packages (from selenium) (2024.2.2)
# Requirement already satisfied: typing_extensions~=4.9 in c:\programdata\anaconda3\lib\site-packages (from selenium) (4.9.0)
# Collecting websocket-client~=1.8 (from selenium)
#   Downloading websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting attrs>=23.2.0 (from trio~=0.17->selenium)
#   Downloading attrs-24.2.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: sortedcontainers in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Collecting outcome (from trio~=0.17->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.16.0)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\programdata\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Collecting h11<1,>=0.9.0 (from wsproto>=0.14->trio-websocket~=0.9->selenium)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Downloading selenium-4.23.1-py3-none-any.whl (9.4 MB)
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    ---------------------------------------- 0.1/9.4 MB 3.0 MB/s eta 0:00:04
#    -- ------------------------------------- 0.6/9.4 MB 7.4 MB/s eta 0:00:02
#    -------- ------------------------------- 1.9/9.4 MB 15.1 MB/s eta 0:00:01
#    -------------- ------------------------- 3.5/9.4 MB 20.5 MB/s eta 0:00:01
#    -------------------- ------------------- 4.8/9.4 MB 21.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.7/9.4 MB 25.2 MB/s eta 0:00:01
#    ------------------------------------- -- 8.8/9.4 MB 28.1 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.4 MB 27.4 MB/s eta 0:00:01
#    ---------------------------------------- 9.4/9.4 MB 24.2 MB/s eta 0:00:00
# Downloading trio-0.26.2-py3-none-any.whl (475 kB)
#    ---------------------------------------- 0.0/476.0 kB ? eta -:--:--
#    --------------------------------------- 476.0/476.0 kB 31.1 MB/s eta 0:00:00
# Downloading trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Downloading websocket_client-1.8.0-py3-none-any.whl (58 kB)
#    ---------------------------------------- 0.0/58.8 kB ? eta -:--:--
#    ---------------------------------------- 58.8/58.8 kB ? eta 0:00:00
# Downloading attrs-24.2.0-py3-none-any.whl (63 kB)
#    ---------------------------------------- 0.0/63.0 kB ? eta -:--:--
#    ---------------------------------------- 63.0/63.0 kB ? eta 0:00:00
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ---------------------------------------- 0.0/58.3 kB ? eta -:--:--
#    ---------------------------------------- 58.3/58.3 kB ? eta 0:00:00
# Installing collected packages: websocket-client, h11, attrs, wsproto, outcome, trio, trio-websocket, selenium
# Successfully installed attrs-24.2.0 h11-0.14.0 outcome-1.3.0.post0 selenium-4.23.1 trio-0.26.2 trio-websocket-0.11.1 websocket-client-1.8.0 wsproto-1.2.0
#   WARNING: The script wsdump.exe is installed in 'C:\Users\Michael 2023\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
#Imports
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options

url_rank = 'https://www.basketball-reference.com/leagues/NBA_{}_standings.html'

for year in years:
    url = url_rank.format(year)

    # Set up Chrome options
    chrome_options = Options()

    # Automatically download and use the correct ChromeDriver version
    driver = webdriver.Chrome(options=chrome_options)

    # Now you can use the driver to open websites
    driver.get(url)

    driver.execute_script('window.scrollTo(1,10000)')

    time.sleep(10)

    html = driver.page_source

    # Close the browser
    driver.quit()
    
    with open('rank/{}_standing.html'.format(year),'w+',encoding='utf-8') as f:
        f.write(html)

# %%
#Lets extract team stats table for every year
df_rank = []

for year in years:
    with open('rank/{}_standing.html'.format(year), encoding='utf-8') as f:
        page = f.read()
    
    soup = BeautifulSoup(page, 'html.parser')
    rank_table = soup.find(id='all_expanded_standings')
    rank = pd.read_html(str(rank_table))[0]
    rank['Year'] = year
    
    df_rank.append(rank)

# %%
team_rank = pd.concat(df_rank)

# %%
team_rank.head()
# Out:
#   Unnamed: 0_level_0   Unnamed: 1_level_0 Unnamed: 2_level_0 Place         \
#                   Rk                 Team            Overall  Home   Road
# 0                  1       Boston Celtics              61-21  35-6  26-15
# 1                  2   Los Angeles Lakers              60-22  37-4  23-18
# 2                  3   Philadelphia 76ers              59-23  36-5  23-18
# 3                  4  Seattle SuperSonics              56-26  33-8  23-18
# 4                  5         Phoenix Suns              55-27  37-5  18-22
#
#   Conference        Division               ... Month        Year Month       \
#            E      W        A      C     M  ...   Feb   Mar         Apr  May
# 0      45-15   16-6     17-7   28-8   9-1  ...   9-2  12-6  1980   NaN  NaN
# 1       18-4  42-18      8-2   10-2  23-7  ...   9-2  13-3  1980   NaN  NaN
# 2      44-16   15-7     19-5  25-11   7-3  ...  10-3  11-6  1980   NaN  NaN
# 3       17-5  39-21      7-3   10-2  21-9  ...   9-4   9-6  1980   NaN  NaN
# 4       13-9  42-18      5-5    8-4  23-7  ...   8-5  12-3  1980   NaN  NaN
#
#   Division           Month
#         SE   NW   SW   Jul  Aug
# 0      NaN  NaN  NaN   NaN  NaN
# 1      NaN  NaN  NaN   NaN  NaN
# 2      NaN  NaN  NaN   NaN  NaN
# 3      NaN  NaN  NaN   NaN  NaN
# 4      NaN  NaN  NaN   NaN  NaN
#
# [5 rows x 29 columns]

# %%
#Dropping the top-level header
team_rank.columns = team_rank.columns.droplevel(0)
team_rank.head()
# Out:
#    Rk                 Team Overall  Home   Road      E      W     A      C  \
# 0   1       Boston Celtics   61-21  35-6  26-15  45-15   16-6  17-7   28-8
# 1   2   Los Angeles Lakers   60-22  37-4  23-18   18-4  42-18   8-2   10-2
# 2   3   Philadelphia 76ers   59-23  36-5  23-18  44-16   15-7  19-5  25-11
# 3   4  Seattle SuperSonics   56-26  33-8  23-18   17-5  39-21   7-3   10-2
# 4   5         Phoenix Suns   55-27  37-5  18-22   13-9  42-18   5-5    8-4
#
#       M  ...   Feb   Mar        Apr  May   SE   NW   SW  Jul  Aug
# 0   9-1  ...   9-2  12-6  1980  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1  23-7  ...   9-2  13-3  1980  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2   7-3  ...  10-3  11-6  1980  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3  21-9  ...   9-4   9-6  1980  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4  23-7  ...   8-5  12-3  1980  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 29 columns]

# %%
#Store dataframe into a csv file
team_rank.to_csv('team_rank.csv')
